# %%
import author

story: author.Story = author.run()
# Out:
# Story(title='The Scruffle-Faced Dad and the Blue-Eyed Lass', summary='Meet a tall, scratchy Dad, a beautiful brunette Mom, and their darling six-month-old Lennon with eyes as blue as the Zubber-Zane sky in this Seussian tale of family fun.', pages=['In the house on the hill lived a family of three, as happy as any three people could be! There was Dad, who was tall, with a face full of scruff, a scratchy, old face that was wonderfully rough.', 'And Mom, with her hair of a deep, brunette glow, the loveliest lady that anyone would know! She smiled a big smile and she danced through the hall, the kindest, most beautiful mother of all.', 'But the star of the show was little Miss Len, the cutest young daughter that lived in the glen. At six months of age, she was tiny and wise, with the brightest and bluest of big, roundy eyes!', 'So Dad gave a tickle with scratchy-face glee, while Mom sang a song for the baby to see. With Lennon’s blue eyes shining bright as the sun, their whimsical morni
# ...

# %%
import illustrator

illustrations: illustrator.Illustrations = illustrator.run(story)
# illustrations.display()

# %%
import reader

narration = reader.run(story)
narration.audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
import publisher

publication = publisher.run(story, illustrations, narration)
publication
# Out:
# /Users/parker/Development/storytime/.venv/lib/python3.11/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/parker/Development/storytime/.venv/lib/python3.11/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 'gs://storytime-share/the-scruff-the-brunette-and-the-blue-eyed-glee/'
